# %%
# 이건 중국전용
import openai
import json
import os

def read_descriptions(file_path):
    # 파일을 읽기 모드로 열기
    with open(file_path, 'r', encoding='utf-8') as file:
        # JSON 데이터 로드
        data = json.load(file)
    
    return data

def call_chatgpt(news_content):
    # 환경변수에서 API 키 불러오기
    api_key = 'sk-al8LY2KP9JUls1HdCrdrhA2GofI2OztrBR3w1W6pErT3BlbkFJsLFqgNeJKhTgVR3VIBIHVaZ1qvi5FNsS_cBG7rTGIA'
    openai.api_key = api_key
    
    content = """
        너는 외환분야, 특히 "원/위안화" 분야 전문인 경제 전문가야. 사용자가 외환 관련 뉴스를 전달하면, 해당 뉴스를 '원/위안화' 환율과 연결하여 요약, 분석, 평가하고 그 결과를 최종 판단과 함께 사용자에게 전달하는 역할을 하고 있어.
        "Daily240913.pdf":
        글로벌 주요 통화 대비 미국 달러 지수(USD Index)는 원/달러 환율에 중요한 지표로, 달러 지수의 강세는 원/달러 환율 상승을 촉진할 수 있어.
        유가, 금리 인상 전망, 그리고 국제 유동성은 달러 가치에 영향을 미치며, 이는 원화에도 직접적인 영향을 미칠 수 있어. 이 보고서는 미국의 강력한 경제 지표가 달러 강세를 뒷받침할 때, 원/달러 환율 상승 가능성을 시사하고 있어.
        또한 미국 경제 회복 속도에 따라 달러화 수요가 증대될 수 있음을 염두에 두고, PPI(생산자물가지수)와 같은 인플레이션 지표도 환율 변동성을 예측하는 데 중요한 역할을 한다는 점을 강조해.
        "Weekly240909.pdf":
        중국 경기 둔화 및 그로 인한 위안화 약세가 원화 약세를 유발할 수 있음. 원/달러 환율은 위안화와 밀접한 관계가 있으며, 특히 중국의 경제적 둔화가 원/달러 환율에 악영향을 미치는지 분석할 필요가 있어.
        ECB(유럽중앙은행)의 금리 정책이 달러화와 유로화 간의 관계에 영향을 미치고, 이는 다시 원/달러 환율에 연쇄적인 영향을 줄 수 있어. 주간 분석은 유럽 경제 상황이 글로벌 외환 시장에서 중요한 변수로 작용할 수 있음을 나타냄.
        미국 연준(Fed)의 금리 정책은 장기적으로 원/달러 환율에 가장 큰 영향을 미치며, 이는 다른 주요 글로벌 경제 동향과 결합되어 환율을 변화시킬 수 있음. 특히 금리 인상이나 경기 부양책에 대한 논의가 환율 상승으로 이어질 수 있음.
        "semi2024.pdf":
        2024년 한국 경제 전망에서는 GDP 성장률, 달러 인덱스(DXY), 주요 통화 간의 환율 변동성이 원/달러 환율에 미치는 영향을 주목할 필요가 있어.
        한국 경제는 글로벌 경제 흐름에 민감하게 반응하는데, 특히 미국 경제와의 상관관계가 크기 때문에, DXY와 같은 지표가 원/달러 환율에 미치는 영향을 분석할 필요가 있어.
        2024년 원/달러 환율은 중국과 미국 경제 정책에 크게 좌우될 것으로 예상되며, 특히 글로벌 공급망 회복과 경제 성장 속도가 달러 가치에 큰 영향을 미칠 것임.
        경제 성장과 유동성, 국제 무역, 그리고 지정학적 리스크 등 다양한 요인이 원/달러 환율에 복합적으로 영향을 미칠 것으로 전망됨.
        따라서 이 보고서들에서 제공된 데이터를 기반으로, 원/달러 환율 분석에 미국 경제 지표와 글로벌 유동성, 중국 경제 상황 등을 고려하여 더 정확한 판단을 제공해야 해. 또한, 국제 경제 흐름이 원/달러 환율에 미치는 영향을 분석할 때, 유럽과 미국의 금리 변동성, 그리고 중국 경제 상황을 중요한 요소로 간주해야 해. 그리고 너에게 주어질 문서는 영어이고, 양식에 맞게 한국어로 번역해서 반환해야해.
        양식은 "news_summary" : "요약내용", "news_analysis" : "분석내용", "result" : "결론", "title":"제목번역", "content":"본문내용" 이거고 참고로 result에 들어갈 내용은 '호재'와 '악재' 둘 중 하나만 들어가야 해. 외환관련된 기사가 아니더라도 반드시 "원/위안화"와 연관시켜 분석하고, "news_summary", "news_analysis", "result", "title", "content"를 일관성 있게 json 양식으로 반환해.
        """
    try:
        response = openai.ChatCompletion.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": content},
                {"role": "user", "content": news_content}
            ],
            max_tokens=2000
        )

        response_content = response['choices'][0]['message']['content'] if 'message' in response['choices'][0] else response['choices'][0]['text']
        
        return response_content
    except Exception as e:
        print(f"API 호출 중 에러 발생: {e}")
        return None

def main():
    file_path_read = '/Users/yang-jin-an/news_data_20_CNY.json'
    file_path_write = 'chatgpt_data_CNY.json'
    
    news_data = read_descriptions(file_path_read)
    results = []
    
    for item in news_data:
        news_content = item.get('content', 'No description provided')
        response_content = call_chatgpt(news_content)
        print(response_content)


if __name__ == "__main__":
    main()

# %%
import openai
import json
import mysql.connector

# MySQL 연결 정보 설정
config = {
    'user': 'yangjinan',
    'password': 'ALsk85200!!',
    'host': 'hanaex.mysql.database.azure.com',
    'database': 'my_database',
    'port': 3306
}

def read_descriptions(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

def call_chatgpt(news_content):
    api_key = 'sk-al8LY2KP9JUls1HdCrdrhA2GofI2OztrBR3w1W6pErT3BlbkFJsLFqgNeJKhTgVR3VIBIHVaZ1qvi5FNsS_cBG7rTGIA'
    openai.api_key = api_key
    
    content = """
        너는 외환분야, 특히 "원/위안화" 분야 전문인 경제 전문가야. 사용자가 외환 관련 뉴스를 전달하면, 해당 뉴스를 '원/위안화' 환율과 연결하여 요약, 분석, 평가하고 그 결과를 최종 판단과 함께 사용자에게 전달하는 역할을 하고 있어.
        "Daily240913.pdf":
        글로벌 주요 통화 대비 미국 달러 지수(USD Index)는 원/달러 환율에 중요한 지표로, 달러 지수의 강세는 원/달러 환율 상승을 촉진할 수 있어.
        유가, 금리 인상 전망, 그리고 국제 유동성은 달러 가치에 영향을 미치며, 이는 원화에도 직접적인 영향을 미칠 수 있어. 이 보고서는 미국의 강력한 경제 지표가 달러 강세를 뒷받침할 때, 원/달러 환율 상승 가능성을 시사하고 있어.
        또한 미국 경제 회복 속도에 따라 달러화 수요가 증대될 수 있음을 염두에 두고, PPI(생산자물가지수)와 같은 인플레이션 지표도 환율 변동성을 예측하는 데 중요한 역할을 한다는 점을 강조해.
        "Weekly240909.pdf":
        중국 경기 둔화 및 그로 인한 위안화 약세가 원화 약세를 유발할 수 있음. 원/달러 환율은 위안화와 밀접한 관계가 있으며, 특히 중국의 경제적 둔화가 원/달러 환율에 악영향을 미치는지 분석할 필요가 있어.
        ECB(유럽중앙은행)의 금리 정책이 달러화와 유로화 간의 관계에 영향을 미치고, 이는 다시 원/달러 환율에 연쇄적인 영향을 줄 수 있어. 주간 분석은 유럽 경제 상황이 글로벌 외환 시장에서 중요한 변수로 작용할 수 있음을 나타냄.
        미국 연준(Fed)의 금리 정책은 장기적으로 원/달러 환율에 가장 큰 영향을 미치며, 이는 다른 주요 글로벌 경제 동향과 결합되어 환율을 변화시킬 수 있음. 특히 금리 인상이나 경기 부양책에 대한 논의가 환율 상승으로 이어질 수 있음.
        "semi2024.pdf":
        2024년 한국 경제 전망에서는 GDP 성장률, 달러 인덱스(DXY), 주요 통화 간의 환율 변동성이 원/달러 환율에 미치는 영향을 주목할 필요가 있어.
        한국 경제는 글로벌 경제 흐름에 민감하게 반응하는데, 특히 미국 경제와의 상관관계가 크기 때문에, DXY와 같은 지표가 원/달러 환율에 미치는 영향을 분석할 필요가 있어.
        2024년 원/달러 환율은 중국과 미국 경제 정책에 크게 좌우될 것으로 예상되며, 특히 글로벌 공급망 회복과 경제 성장 속도가 달러 가치에 큰 영향을 미칠 것임.
        경제 성장과 유동성, 국제 무역, 그리고 지정학적 리스크 등 다양한 요인이 원/달러 환율에 복합적으로 영향을 미칠 것으로 전망됨.
        따라서 이 보고서들에서 제공된 데이터를 기반으로, 원/달러 환율 분석에 미국 경제 지표와 글로벌 유동성, 중국 경제 상황 등을 고려하여 더 정확한 판단을 제공해야 해. 또한, 국제 경제 흐름이 원/달러 환율에 미치는 영향을 분석할 때, 유럽과 미국의 금리 변동성, 그리고 중국 경제 상황을 중요한 요소로 간주해야 해. 그리고 너에게 주어질 문서는 영어이고, 양식에 맞게 한국어로 번역해서 반환해야해.
        양식은 "news_summary" : "요약내용", "news_analysis" : "분석내용", "result" : "결론", "title":"제목번역", "content":"본문내용" 이거고 참고로 result에 들어갈 내용은 '호재'와 '악재' 둘 중 하나만 들어가야 해. 외환관련된 기사가 아니더라도 반드시 "원/위안화"와 연관시켜 분석하고, "news_summary", "news_analysis", "result", "title", "content"를 일관성 있게 json 양식으로 반환해.
        """
    
    try:
        response = openai.ChatCompletion.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": content},
                {"role": "user", "content": news_content}
            ],
            max_tokens=2000
        )

        response_content = response['choices'][0]['message']['content'] if 'message' in response['choices'][0] else response['choices'][0]['text']
        return json.loads(response_content)  # response_content를 json으로 변환
    except Exception as e:
        print(f"API 호출 중 에러 발생: {e}")
        return None

def insert_into_database(news_data, response_content):
    try:
        connection = mysql.connector.connect(**config)
        cursor = connection.cursor()

        # 데이터베이스 삽입 SQL 쿼리 작성
        sql_query = """
        INSERT INTO news_table (state, url, title, image_url, content, news_summary, result, news_analysis, source)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
        """

        # 데이터 삽입
        cursor.execute(sql_query, (
            "CNY",  # state
            news_data['url'],  # URL
            news_data['title'],  # Title
            news_data['image_url'],  # Image URL
            news_data['content'],  # Content
            response_content.get('news_summary'),  # News Summary
            response_content.get('result'),  # Result (호재/악재)
            response_content.get('news_analysis'),  # News Analysis
            "KOREA"  # Source
        ))

        # 커밋
        connection.commit()
        print(f"뉴스 '{news_data['title']}'가 데이터베이스에 성공적으로 삽입되었습니다.")

    except mysql.connector.Error as error:
        print(f"데이터 삽입 중 오류 발생: {error}")
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()

def main():
    file_path_read = 'news_data_20_CNY.json'
    
    # 뉴스 데이터 읽기
    news_data_list = read_descriptions(file_path_read)
    
    for news_data in news_data_list:
        news_content = news_data.get('content', 'No description provided')
        
        # ChatGPT API 호출
        response_content = call_chatgpt(news_content)
        
        if response_content:
            # DB에 저장
            insert_into_database(news_data, response_content)
        else:
            print(f"'{news_data['title']}'에 대한 응답이 없습니다.")

if __name__ == "__main__":
    main()

# %%
import openai
import json
import mysql.connector

# MySQL 연결 정보 설정
config = {
    'user': 'yangjinan',
    'password': 'ALsk85200!!',
    'host': 'hanaex.mysql.database.azure.com',
    'database': 'my_database',
    'port': 3306
}

def read_descriptions(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

def call_chatgpt(news_content):
    api_key = 'sk-al8LY2KP9JUls1HdCrdrhA2GofI2OztrBR3w1W6pErT3BlbkFJsLFqgNeJKhTgVR3VIBIHVaZ1qvi5FNsS_cBG7rTGIA'
    openai.api_key = api_key
    
    content = """
            너는 외환분야, 특히 "원/위안화" 분야 전문인 경제 전문가야. 사용자가 외환 관련 뉴스를 전달하면, 해당 뉴스를 '원/위안화' 환율과 연결하여 요약, 분석, 평가하고 그 결과를 최종 판단과 함께 사용자에게 전달하는 역할을 하고 있어.
            "Daily240913.pdf":
            글로벌 주요 통화 대비 미국 달러 지수(USD Index)는 원/달러 환율에 중요한 지표로, 달러 지수의 강세는 원/달러 환율 상승을 촉진할 수 있어.
            유가, 금리 인상 전망, 그리고 국제 유동성은 달러 가치에 영향을 미치며, 이는 원화에도 직접적인 영향을 미칠 수 있어. 이 보고서는 미국의 강력한 경제 지표가 달러 강세를 뒷받침할 때, 원/달러 환율 상승 가능성을 시사하고 있어.
            또한 미국 경제 회복 속도에 따라 달러화 수요가 증대될 수 있음을 염두에 두고, PPI(생산자물가지수)와 같은 인플레이션 지표도 환율 변동성을 예측하는 데 중요한 역할을 한다는 점을 강조해.
            "Weekly240909.pdf":
            중국 경기 둔화 및 그로 인한 위안화 약세가 원화 약세를 유발할 수 있음. 원/달러 환율은 위안화와 밀접한 관계가 있으며, 특히 중국의 경제적 둔화가 원/달러 환율에 악영향을 미치는지 분석할 필요가 있어.
            ECB(유럽중앙은행)의 금리 정책이 달러화와 유로화 간의 관계에 영향을 미치고, 이는 다시 원/달러 환율에 연쇄적인 영향을 줄 수 있어. 주간 분석은 유럽 경제 상황이 글로벌 외환 시장에서 중요한 변수로 작용할 수 있음을 나타냄.
            미국 연준(Fed)의 금리 정책은 장기적으로 원/달러 환율에 가장 큰 영향을 미치며, 이는 다른 주요 글로벌 경제 동향과 결합되어 환율을 변화시킬 수 있음. 특히 금리 인상이나 경기 부양책에 대한 논의가 환율 상승으로 이어질 수 있음.
            "semi2024.pdf":
            2024년 한국 경제 전망에서는 GDP 성장률, 달러 인덱스(DXY), 주요 통화 간의 환율 변동성이 원/달러 환율에 미치는 영향을 주목할 필요가 있어.
            한국 경제는 글로벌 경제 흐름에 민감하게 반응하는데, 특히 미국 경제와의 상관관계가 크기 때문에, DXY와 같은 지표가 원/달러 환율에 미치는 영향을 분석할 필요가 있어.
            2024년 원/달러 환율은 중국과 미국 경제 정책에 크게 좌우될 것으로 예상되며, 특히 글로벌 공급망 회복과 경제 성장 속도가 달러 가치에 큰 영향을 미칠 것임.
            경제 성장과 유동성, 국제 무역, 그리고 지정학적 리스크 등 다양한 요인이 원/달러 환율에 복합적으로 영향을 미칠 것으로 전망됨.
            따라서 이 보고서들에서 제공된 데이터를 기반으로, 원/달러 환율 분석에 미국 경제 지표와 글로벌 유동성, 중국 경제 상황 등을 고려하여 더 정확한 판단을 제공해야 해. 또한, 국제 경제 흐름이 원/달러 환율에 미치는 영향을 분석할 때, 유럽과 미국의 금리 변동성, 그리고 중국 경제 상황을 중요한 요소로 간주해야 해. 그리고 너에게 주어질 문서는 영어이고, 양식에 맞게 한국어로 번역해서 반환해야해.
            양식은 "news_summary" : "요약내용", "news_analysis" : "분석내용", "result" : "결론", "title":"제목번역", "content":"본문내용" 이거고 참고로 result에 들어갈 내용은 '호재'와 '악재' 둘 중 하나만 들어가야 해. 외환관련된 기사가 아니더라도 반드시 "원/위안화"와 연관시켜 분석하고, "news_summary", "news_analysis", "result", "title", "content"를 일관성 있게 json 양식으로 반환해.
        """
    
    try:
        response = openai.ChatCompletion.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": content},
                {"role": "user", "content": news_content}
            ],
            max_tokens=2000
        )

        response_content = response['choices'][0]['message']['content'] if 'message' in response['choices'][0] else response['choices'][0]['text']
        return json.loads(response_content)  # response_content를 json으로 변환
    except Exception as e:
        print(f"API 호출 중 에러 발생: {e}")
        return None

def insert_into_database(news_data, response_content):
    try:
        connection = mysql.connector.connect(**config)
        cursor = connection.cursor()

        # 데이터베이스 삽입 SQL 쿼리 작성
        sql_query = """
        INSERT INTO news_table (state, url, title, image_url, content, news_summary, result, news_analysis, source)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
        """

        # 데이터 삽입
        cursor.execute(sql_query, (
            "CNY",  # state
            news_data['url'],  # URL
            news_data['title'],  # Title
            news_data['image_url'],  # Image URL
            news_data['content'],  # Content
            response_content.get('news_summary'),  # News Summary
            response_content.get('result'),  # Result (호재/악재)
            response_content.get('news_analysis'),  # News Analysis
            "KOREA"  # Source
        ))

        # 커밋
        connection.commit()
        return True

    except mysql.connector.Error as error:
        print(f"데이터 삽입 중 오류 발생: {error}")
        return False
    finally:
        if connection.is_connected():
            cursor.close()
            connection.close()

def main():
    file_path_read = 'news_data_20_CNY.json'
    
    # 뉴스 데이터 읽기
    news_data_list = read_descriptions(file_path_read)
    success_count = 0  # 성공적으로 저장된 뉴스 카운트
    
    for idx, news_data in enumerate(news_data_list):
        news_content = news_data.get('content', 'No description provided')
        
        # ChatGPT API 호출
        response_content = call_chatgpt(news_content)
        
        if response_content:
            # DB에 저장하고 성공 여부 확인
            if insert_into_database(news_data, response_content):
                success_count += 1
                print(f"{success_count}개째 뉴스 '{news_data['title']}'가 데이터베이스에 저장되었습니다.")
        else:
            print(f"'{news_data['title']}'에 대한 응답이 없습니다.")
    
    # 총 저장된 뉴스 수 출력
    print(f"총 {success_count}개의 뉴스가 데이터베이스에 저장되었습니다.")

if __name__ == "__main__":
    main()
# Out:
# 1개째 뉴스 '“뭘 해도 이건 하지마”…학을 뗀 중학개미들, 수익률 얼마나 처참하길래'가 데이터베이스에 저장되었습니다.
# 2개째 뉴스 '“달러 버리는 나라, 관세 100% 때리겠다”…트럼프의 엄포가 무서운 이유'가 데이터베이스에 저장되었습니다.
# 3개째 뉴스 '확이냐 찔끔이냐…미국 금리인하 놓고 전세계가 옥신각신'가 데이터베이스에 저장되었습니다.
# 4개째 뉴스 '‘5% 달성’ 눈앞 … 위안화 국제결제 비중 역대 최대'가 데이터베이스에 저장되었습니다.
# 5개째 뉴스 '위안화 국경 간 거래량 역대 최고치...“中·러 거래 급증 때문”'가 데이터베이스에 저장되었습니다.
# 6개째 뉴스 '“얼굴 다 고쳤다” 홍수아, ‘솔직 당당’ 성형 고백(노빠꾸탁재훈)'가 데이터베이스에 저장되었습니다.
# 7개째 뉴스 '엔 캐리 지고 위안화 캐리 뜬다'가 데이터베이스에 저장되었습니다.
# 8개째 뉴스 '“이번엔 진짜 믿어주세요”…증권가 3분기에도 ‘이 업종’ 꼽았다'가 데이터베이스에 저장되었습니다.
# 9개째 뉴스 '“전세계 주가폭락 사태 원흉, 아직 죽지 않았다”…엔캐리 청산 리스크에 대한 경계 [매경데스크]'가 데이터베이스에 저장되었습니다.
# 10개째 뉴스 '중국·일본 으르렁 대는데…난데 없이 뛰어든 이 남자, 속셈은'가 데이터베이스에 저장되었습니다.
# 11개째 뉴스 '서울역·논현동서 신한은행 ATM으로 외화 환전'가 데이터베이스에 저장되었습니다.
# 12개째 뉴스 '엔화값 상승이 자산시장에 갖는 의미 [매일 돈이 보이는 습관 M+]'가 데이터베이스에 저장되었습니다.
# 13개째 뉴스 '“트럼프 당선 확신하면 이것 사라”...횡보장서 ‘랠리 예측’ 나오는 이유'가 데이터베이스에 저장되었습니다.
# ---------------------------------------------------------------------------
# ...
